# %%
import os,time,sys
import matplotlib.pyplot as plt 
import numpy as np
from charon import propa
from charon import profile
import charon.physicsconstants as PC
pc = PC.PhysicsConstants()
from Spectra_functions import Spectra_extrapolate, Flux_interpolation, Signal_PDF
from scipy.interpolate import splrep, splev
from ipynb.fs.full.func_plot_histo import plot_projections

# %%
Flux_nue_source_NFW = Spectra_extrapolate(mass=1e7, channel = 'nuenue', process="decay", source=True, galactic_profile=profile.NFW)
Flux_nue_osc_NFW = Spectra_extrapolate(mass=1e7, channel = 'nuenue', process="decay", source=False, galactic_profile=profile.NFW)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Flux_nue_source_Burkert = Spectra_extrapolate(mass=1e7, channel = 'nuenue', process="decay", source=True, galactic_profile=profile.Burkert)
Flux_nue_osc_Burkert = Spectra_extrapolate(mass=1e7, channel = 'nuenue', process="decay", source=False, galactic_profile=profile.Burkert)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Flux_numu_source_NFW = Spectra_extrapolate(mass=1e7, channel = 'numunumu', process="decay", source=True, galactic_profile=profile.NFW)
Flux_numu_osc_NFW = Spectra_extrapolate(mass=1e7, channel = 'numunumu', process="decay", source=False, galactic_profile=profile.NFW)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Flux_numu_source_Burkert = Spectra_extrapolate(mass=1e7, channel = 'numunumu', process="decay", source=True, galactic_profile=profile.Burkert)
Flux_numu_osc_Burkert = Spectra_extrapolate(mass=1e7, channel = 'numunumu', process="decay", source=False, galactic_profile=profile.Burkert)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Flux_nutau_source_NFW = Spectra_extrapolate(mass=1e7, channel = 'nutaunutau', process="decay", source=True, galactic_profile=profile.NFW)
Flux_nutau_osc_NFW = Spectra_extrapolate(mass=1e7, channel = 'nutaunutau', process="decay", source=False, galactic_profile=profile.NFW)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Flux_nutau_source_Burkert = Spectra_extrapolate(mass=1e7, channel = 'nutaunutau', process="decay", source=True, galactic_profile=profile.Burkert)
Flux_nutau_osc_Burkert = Spectra_extrapolate(mass=1e7, channel = 'nutaunutau', process="decay", source=False, galactic_profile=profile.Burkert)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nue_NFW1 = Signal_PDF(mass=1e6, channel='nuenue',process='decay',galactic_profile=profile.NFW, extrapolation=False)
Reco_rate_nue_Burkert1 = Signal_PDF(mass=1e6, channel='nuenue',process='decay',galactic_profile=profile.Burkert,extrapolation=False)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_numu_NFW1 = Signal_PDF(mass=1e6, channel='numunumu',process='decay',galactic_profile=profile.NFW, extrapolation=False)
Reco_rate_numu_Burkert1 = Signal_PDF(mass=1e6, channel='numunumu',process='decay',galactic_profile=profile.Burkert,extrapolation=False)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nutau_NFW1 = Signal_PDF(mass=1e6, channel='nutaunutau',process='decay',galactic_profile=profile.NFW, extrapolation=False)
Reco_rate_nutau_Burkert1 = Signal_PDF(mass=1e6, channel='nutaunutau',process='decay',galactic_profile=profile.Burkert, extrapolation=False)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nue_NFW = Signal_PDF(mass=1e7, channel='nuenue',process='decay',galactic_profile=profile.NFW, extrapolation=True)
Reco_rate_nue_Burkert = Signal_PDF(mass=1e7, channel='nuenue',process='decay',galactic_profile=profile.Burkert,extrapolation=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nue_NFW100 = Signal_PDF(mass=1e8, channel='nuenue',process='decay',galactic_profile=profile.NFW, extrapolation=True)
Reco_rate_nue_Burkert100 = Signal_PDF(mass=1e8, channel='nuenue',process='decay',galactic_profile=profile.Burkert,extrapolation=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_numu_NFW = Signal_PDF(mass=1e7, channel='numunumu',process='decay',galactic_profile=profile.NFW, extrapolation=True)
Reco_rate_numu_Burkert = Signal_PDF(mass=1e7, channel='numunumu',process='decay',galactic_profile=profile.Burkert,extrapolation=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_numu_NFW100 = Signal_PDF(mass=1e8, channel='numunumu',process='decay',galactic_profile=profile.NFW, extrapolation=True)
Reco_rate_numu_Burkert100 = Signal_PDF(mass=1e8, channel='numunumu',process='decay',galactic_profile=profile.Burkert,extrapolation=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nutau_NFW = Signal_PDF(mass=1e7, channel='nutaunutau',process='decay',galactic_profile=profile.NFW, extrapolation=True)
Reco_rate_nutau_Burkert = Signal_PDF(mass=1e7, channel='nutaunutau',process='decay',galactic_profile=profile.Burkert, extrapolation=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nutau_NFW100 = Signal_PDF(mass=1e8, channel='nutaunutau',process='decay',galactic_profile=profile.NFW, extrapolation=True)
Reco_rate_nutau_Burkert100 = Signal_PDF(mass=1e8, channel='nutaunutau',process='decay',galactic_profile=profile.Burkert, extrapolation=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nue_NFW1000 = Signal_PDF(mass=1e9, channel='nuenue',process='decay',galactic_profile=profile.NFW, extrapolation=True)
Reco_rate_nue_Burkert1000 = Signal_PDF(mass=1e9, channel='nuenue',process='decay',galactic_profile=profile.Burkert,extrapolation=True)
Reco_rate_numu_NFW1000 = Signal_PDF(mass=1e9, channel='numunumu',process='decay',galactic_profile=profile.NFW, extrapolation=True)
Reco_rate_numu_Burkert1000 = Signal_PDF(mass=1e9, channel='numunumu',process='decay',galactic_profile=profile.Burkert,extrapolation=True)
Reco_rate_nutau_NFW1000 = Signal_PDF(mass=1e9, channel='nutaunutau',process='decay',galactic_profile=profile.NFW, extrapolation=True)
Reco_rate_nutau_Burkert1000 = Signal_PDF(mass=1e9, channel='nutaunutau',process='decay',galactic_profile=profile.Burkert, extrapolation=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# ...

# %%
resp_matrix_data = np.load('/home/dvaldenaire/Python/Analysis/Response matrix/Resp_MC1122_logE.pkl',allow_pickle=True, encoding="latin1")
Reco_mass_edges = np.log10(resp_matrix_data['Bin']['reco_energy_edges'])
Reco_theta_edges = resp_matrix_data['Bin']['reco_psi_edges']

# %%
plot_projections(Reco_rate_nue_NFW1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nuenue | m = 1 PeV | decay')
plot_projections(Reco_rate_nue_Burkert1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nuenue | m = 1 PeV | decay')

# %%
plot_projections(Reco_rate_numu_NFW1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW numunumu | m = 1 PeV | decay')
plot_projections(Reco_rate_numu_Burkert1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert numunumu | m = 1 PeV | decay')

# %%
plot_projections(Reco_rate_nutau_NFW1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nutaunutau | m = 1 PeV | decay')
plot_projections(Reco_rate_nutau_Burkert1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nutaunutau | m = 1 PeV | decay')

# %%
plot_projections(Reco_rate_nue_NFW,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nuenue | m = 10 PeV | decay')
plot_projections(Reco_rate_nue_Burkert,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nuenue | m = 10 PeV | decay')

# %%
plot_projections(Reco_rate_numu_NFW,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW numunumu | m = 10 PeV | decay')
plot_projections(Reco_rate_numu_Burkert,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert numunumu | m = 10 PeV | decay')

# %%
plot_projections(Reco_rate_nutau_NFW,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nutaunutau | m = 10 PeV | decay')
plot_projections(Reco_rate_nutau_Burkert,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nutaunutau | m = 10 PeV | decay')

# %%
plot_projections(Reco_rate_nue_NFW100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nuenue | m = 100 PeV | decay')
plot_projections(Reco_rate_nue_Burkert100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nuenue | m = 100 PeV | decay')

# %%
plot_projections(Reco_rate_numu_NFW100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW numunumu | m = 100 PeV | decay')
plot_projections(Reco_rate_numu_Burkert100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert numunumu | m = 100 PeV | decay')

# %%
plot_projections(Reco_rate_nutau_NFW100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nutaunutau | m = 100 PeV | decay')
plot_projections(Reco_rate_nutau_Burkert100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nutaunutau | m = 100 PeV | decay')

# %%
plot_projections(Reco_rate_nue_NFW1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nuenue | m = 1000 PeV | decay')
plot_projections(Reco_rate_nue_Burkert1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nuenue | m = 1000 PeV | decay')

# %%
plot_projections(Reco_rate_numu_NFW1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW numunumu | m = 100 PeV | decay')
plot_projections(Reco_rate_numu_Burkert1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert numunumu | m = 100 PeV | decay')

# %%
plot_projections(Reco_rate_nutau_NFW1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nutaunutau | m = 1000 PeV | decay')
plot_projections(Reco_rate_nutau_Burkert1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nutaunutau | m = 1000 PeV | decay')
