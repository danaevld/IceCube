# %%
import os,time,sys
import matplotlib.pyplot as plt 
import numpy as np
from charon import propa
from charon import profile
import charon.physicsconstants as PC
pc = PC.PhysicsConstants()
from Spectra_functions import Spectra_extrapolate, Flux_interpolation, Signal_PDF, Spectra_generator
from scipy.interpolate import splrep, splev
from ipynb.fs.full.func_plot_histo import plot_projections

# %%
Flux_nue_source = Spectra_extrapolate(mass=1e7, channel = 'nuenue', process="decay", source=True)
Flux_nue_osc = Spectra_extrapolate(mass=1e7, channel = 'nuenue', process="decay", source=False)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Flux_numu_source = Spectra_extrapolate(mass=1e7, channel = 'numunumu', process="decay", source=True)
Flux_numu_osc = Spectra_extrapolate(mass=1e7, channel = 'numunumu', process="decay", source=False)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Flux_nutau_source = Spectra_extrapolate(mass=1e7, channel = 'nutaunutau', process="decay", source=True)
Flux_nutau_osc = Spectra_extrapolate(mass=1e7, channel = 'nutaunutau', process="decay", source=False)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Flux_nutau_source = Spectra_extrapolate(mass=1e7, channel = 'bb', process="decay", source=True)
Flux_nutau_osc = Spectra_extrapolate(mass=1e7, channel = 'bb', process="decay", source=False)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nue_NFW1 = Signal_PDF(mass=1e6, channel='nuenue',process='decay',galactic_profile=profile.NFW, extrapolation=False, normalize=True)
Reco_rate_nue_Burkert1 = Signal_PDF(mass=1e6, channel='nuenue',process='decay',galactic_profile=profile.Burkert,extrapolation=False, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_numu_NFW1 = Signal_PDF(mass=1e6, channel='numunumu',process='decay',galactic_profile=profile.NFW, extrapolation=False, normalize=True)
Reco_rate_numu_Burkert1 = Signal_PDF(mass=1e6, channel='numunumu',process='decay',galactic_profile=profile.Burkert,extrapolation=False, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nutau_NFW1 = Signal_PDF(mass=1e6, channel='nutaunutau',process='decay',galactic_profile=profile.NFW, extrapolation=False, normalize=True)
Reco_rate_nutau_Burkert1 = Signal_PDF(mass=1e6, channel='nutaunutau',process='decay',galactic_profile=profile.Burkert, extrapolation=False, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_bb_NFW1 = Signal_PDF(mass=1e6, channel='bb',process='decay',galactic_profile=profile.NFW, extrapolation=False, normalize=True)
Reco_rate_bb_Burkert1 = Signal_PDF(mass=1e6, channel='bb',process='decay',galactic_profile=profile.Burkert, extrapolation=False, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nue_NFW = Signal_PDF(mass=1e7, channel='nuenue',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_nue_Burkert = Signal_PDF(mass=1e7, channel='nuenue',process='decay',galactic_profile=profile.Burkert,extrapolation=True, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_numu_NFW = Signal_PDF(mass=1e7, channel='numunumu',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_numu_Burkert = Signal_PDF(mass=1e7, channel='numunumu',process='decay',galactic_profile=profile.Burkert,extrapolation=True, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nutau_NFW = Signal_PDF(mass=1e7, channel='nutaunutau',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_nutau_Burkert = Signal_PDF(mass=1e7, channel='nutaunutau',process='decay',galactic_profile=profile.Burkert, extrapolation=True, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_bb_NFW = Signal_PDF(mass=1e7, channel='bb',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_bb_Burkert = Signal_PDF(mass=1e7, channel='bb',process='decay',galactic_profile=profile.Burkert, extrapolation=True, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nue_NFW100 = Signal_PDF(mass=1e8, channel='nuenue',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_nue_Burkert100 = Signal_PDF(mass=1e8, channel='nuenue',process='decay',galactic_profile=profile.Burkert,extrapolation=True, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_numu_NFW100 = Signal_PDF(mass=1e8, channel='numunumu',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_numu_Burkert100 = Signal_PDF(mass=1e8, channel='numunumu',process='decay',galactic_profile=profile.Burkert,extrapolation=True, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nutau_NFW100 = Signal_PDF(mass=1e8, channel='nutaunutau',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_nutau_Burkert100 = Signal_PDF(mass=1e8, channel='nutaunutau',process='decay',galactic_profile=profile.Burkert, extrapolation=True, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_bb_NFW100 = Signal_PDF(mass=1e8, channel='bb',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_bb_Burkert100 = Signal_PDF(mass=1e8, channel='bb',process='decay',galactic_profile=profile.Burkert, extrapolation=True, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5

# %%
Reco_rate_nue_NFW1000 = Signal_PDF(mass=1e9, channel='nuenue',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_nue_Burkert1000 = Signal_PDF(mass=1e9, channel='nuenue',process='decay',galactic_profile=profile.Burkert,extrapolation=True, normalize=True)
Reco_rate_numu_NFW1000 = Signal_PDF(mass=1e9, channel='numunumu',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_numu_Burkert1000 = Signal_PDF(mass=1e9, channel='numunumu',process='decay',galactic_profile=profile.Burkert,extrapolation=True, normalize=True)
Reco_rate_nutau_NFW1000 = Signal_PDF(mass=1e9, channel='nutaunutau',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_nutau_Burkert1000 = Signal_PDF(mass=1e9, channel='nutaunutau',process='decay',galactic_profile=profile.Burkert, extrapolation=True, normalize=True)
Reco_rate_bb_NFW1000 = Signal_PDF(mass=1e9, channel='bb',process='decay',galactic_profile=profile.NFW, extrapolation=True, normalize=True)
Reco_rate_bb_Burkert1000 = Signal_PDF(mass=1e9, channel='bb',process='decay',galactic_profile=profile.Burkert, extrapolation=True, normalize=True)
# Out:
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# Initial Flux Loading: /usr/local/lib/python3.10/dist-packages/charon-0.1.0-py3.10.egg/charon/data/SpectraEW.hdf5
# ...

# %%
resp_matrix_data = np.load('/home/dvaldenaire/Python/Analysis/Response matrix/Resp_MC1122_logE.pkl',allow_pickle=True, encoding="latin1")
Reco_mass_edges = np.log10(resp_matrix_data['Bin']['reco_energy_edges'])
Reco_theta_edges = resp_matrix_data['Bin']['reco_psi_edges']

# %%
plot_projections(Reco_rate_nue_NFW1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nuenue | m = 1 PeV | decay')
plot_projections(Reco_rate_nue_Burkert1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nuenue | m = 1 PeV | decay')

# %%
plot_projections(Reco_rate_numu_NFW1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW numunumu | m = 1 PeV | decay')
plot_projections(Reco_rate_numu_Burkert1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert numunumu | m = 1 PeV | decay')

# %%
plot_projections(Reco_rate_nutau_NFW1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nutaunutau | m = 1 PeV | decay')
plot_projections(Reco_rate_nutau_Burkert1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nutaunutau | m = 1 PeV | decay')

# %%
plot_projections(Reco_rate_bb_NFW1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW bb | m = 1 PeV | decay')
plot_projections(Reco_rate_bb_Burkert1,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert bb | m = 1 PeV | decay')

# %%
plot_projections(Reco_rate_nue_NFW,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nuenue | m = 10 PeV | decay')
plot_projections(Reco_rate_nue_Burkert,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nuenue | m = 10 PeV | decay')

# %%
plot_projections(Reco_rate_numu_NFW,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW numunumu | m = 10 PeV | decay')
plot_projections(Reco_rate_numu_Burkert,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert numunumu | m = 10 PeV | decay')

# %%
plot_projections(Reco_rate_nutau_NFW,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nutaunutau | m = 10 PeV | decay')
plot_projections(Reco_rate_nutau_Burkert,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nutaunutau | m = 10 PeV | decay')

# %%
plot_projections(Reco_rate_bb_NFW,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW bb | m = 10 PeV | decay')
plot_projections(Reco_rate_bb_Burkert,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert bb | m = 10 PeV | decay')

# %%
plot_projections(Reco_rate_nue_NFW100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nuenue | m = 100 PeV | decay')
plot_projections(Reco_rate_nue_Burkert100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nuenue | m = 100 PeV | decay')

# %%
plot_projections(Reco_rate_numu_NFW100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW numunumu | m = 100 PeV | decay')
plot_projections(Reco_rate_numu_Burkert100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert numunumu | m = 100 PeV | decay')

# %%
plot_projections(Reco_rate_nutau_NFW100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nutaunutau | m = 100 PeV | decay')
plot_projections(Reco_rate_nutau_Burkert100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nutaunutau | m = 100 PeV | decay')

# %%
plot_projections(Reco_rate_bb_NFW100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW bb | m = 100 PeV | decay')
plot_projections(Reco_rate_bb_Burkert100,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert bb | m = 100 PeV | decay')

# %%
plot_projections(Reco_rate_nue_NFW1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nuenue | m = 1 EeV | decay')
plot_projections(Reco_rate_nue_Burkert1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nuenue | m = 1 EeV | decay')

# %%
plot_projections(Reco_rate_numu_NFW1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW numunumu | m = 1 EeV | decay')
plot_projections(Reco_rate_numu_Burkert1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert numunumu | m = 1 EeV | decay')

# %%
plot_projections(Reco_rate_nutau_NFW1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW nutaunutau | m = 1 EeV | decay')
plot_projections(Reco_rate_nutau_Burkert1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert nutaunutau | m = 1 EeV | decay')

# %%
plot_projections(Reco_rate_bb_NFW1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','NFW bb | m = 1 EeV | decay')
plot_projections(Reco_rate_bb_Burkert1000,(Reco_theta_edges,Reco_mass_edges),'$\psi_{reco}$ (deg)','$log_{10}(E_{reco})$','Burkert bb | m = 1 EeV | decay')
